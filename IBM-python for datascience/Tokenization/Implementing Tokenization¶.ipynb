# %%
# !pip install nltk
# !pip install transformers==4.42.1
# !pip install sentencepiece
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download de_core_news_sm
# !pip install scikit-learn
# !pip install torch==2.2.2
# !pip install torchtext==0.17.2
# !pip install numpy==1.26.0
# Out:
# Requirement already satisfied: nltk in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: click in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from nltk) (4.67.1)
# Collecting transformers==4.42.1
#   Downloading transformers-4.42.1-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from transformers==4.42.1) (3.20.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from transformers==4.42.1) (0.36.0)
# Collecting numpy<2.0,>=1.17 (from transformers==4.42.1)
#   Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from transformers==4.42.1) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from transformers==4.42.1) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from transformers==4.42.1) (2024.9.11)
# Requirement already satisfied: requests in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from transformers==4.42.1) (2.32.5)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.42.1)
#   Downloading tokenizers-0.19.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from transformers==4.42.1) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from transformers==4.42.1) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42.1) (2026.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42.1) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42.1) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests->transformers==4.42.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests->transformers==4.42.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests->transformers==4.42.1) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests->transformers==4.42.1) (2026.1.4)
# Downloading transformers-4.42.1-py3-none-any.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 18.2 MB/s  0:00:00 eta 0:00:01
# Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Downloading tokenizers-0.19.1-cp311-cp311-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 21.6 MB/s  0:00:00
# Installing collected packages: numpy, tokenizers, transformers
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.2
#     Uninstalling numpy-2.4.2:
#       Successfully uninstalled numpy-2.4.2
#   Attempting uninstall: tokenizers━━━━━━━━━━━━━━ 0/3 [numpy]
#     Found existing installation: tokenizers 0.22.2━━━━━━━━━━━━━━━━ 1/3 [tokenizers]
#     Uninstalling tokenizers-0.22.2:m━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [tokenizers]
#       Successfully uninstalled tokenizers-0.22.2━━━━━━━━━━━━━━ 1/3 [tokenizers]
#   Attempting uninstall: transformers━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [tokenizers]
#     Found existing installation: transformers 4.57.6━━━━━━━━━━ 1/3 [tokenizers]
#     Uninstalling transformers-4.57.6:m╸━━━━━━━━━━━━━ 2/3 [transformers]
#       Successfully uninstalled transformers-4.57.6━━━━━━━━━━━━ 2/3 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [transformers] [transformers]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# litellm 1.81.8 requires openai>=2.8.0, but you have openai 1.83.0 which is incompatible.
# crewai 1.9.3 requires mcp~=1.23.1, but you have mcp 1.15.0 which is incompatible.
# crewai 1.9.3 requires tokenizers~=0.20.3, but you have tokenizers 0.19.1 which is incompatible.
# llama-index-llms-openai 0.6.15 requires openai<3,>=1.108.1, but you have openai 1.83.0 which is incompatible.
# Successfully installed numpy-1.26.4 tokenizers-0.19.1 transformers-4.42.1
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (10 kB)
# Downloading sentencepiece-0.2.1-cp311-cp311-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.5 MB/s  0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.1
# Collecting spacy
#   Downloading spacy-3.8.11-cp311-cp311-macosx_11_0_arm64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.12-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.10-cp311-cp311-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy)
#   Downloading weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from spacy) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from spacy) (2.11.10)
# Requirement already satisfied: jinja2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from spacy) (80.10.2)
# Requirement already satisfied: packaging>=20.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click>=8.0.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.1.8)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (1.17.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from jinja2->spacy) (3.0.3)
# Downloading spacy-3.8.11-cp311-cp311-macosx_11_0_arm64.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 37.0 MB/s  0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.13-cp311-cp311-macosx_11_0_arm64.whl (43 kB)
# Downloading murmurhash-1.0.15-cp311-cp311-macosx_11_0_arm64.whl (27 kB)
# Downloading preshed-3.0.12-cp311-cp311-macosx_11_0_arm64.whl (124 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.2-cp311-cp311-macosx_11_0_arm64.whl (653 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.1/653.1 kB 34.3 MB/s  0:00:00
# Downloading thinc-8.3.10-cp311-cp311-macosx_11_0_arm64.whl (770 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.6/770.6 kB 25.7 MB/s  0:00:00
# Downloading blis-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.3 MB/s  0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.3-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, smart-open, murmurhash, cymem, cloudpathlib, catalogue, blis, srsly, preshed, confection, weasel, thinc, spacy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [spacy]m14/15 [spacy]]
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 murmurhash-1.0.15 preshed-3.0.12 smart-open-7.5.0 spacy-3.8.11 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.2 thinc-8.3.10 wasabi-1.1.3 weasel-0.4.3
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 54.9 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Collecting de-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-3.8.0/de_core_news_sm-3.8.0-py3-none-any.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 63.5 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: de-core-news-sm
# Successfully installed de-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# Requirement already satisfied: scikit-learn in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Collecting torch==2.2.2
#   Downloading torch-2.2.2-cp311-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Requirement already satisfied: filelock in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2) (4.15.0)
# Requirement already satisfied: sympy in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2) (1.14.0)
# Requirement already satisfied: networkx in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2) (3.1.6)
# Requirement already satisfied: fsspec in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2) (2026.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from jinja2->torch==2.2.2) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from sympy->torch==2.2.2) (1.3.0)
# Downloading torch-2.2.2-cp311-none-macosx_11_0_arm64.whl (59.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 MB 12.8 MB/s  0:00:04m0:00:0100:01
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.10.0
#     Uninstalling torch-2.10.0:
#       Successfully uninstalled torch-2.10.0
# Successfully installed torch-2.2.2
# Collecting torchtext==0.17.2
#   Downloading torchtext-0.17.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.9 kB)
# Requirement already satisfied: tqdm in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torchtext==0.17.2) (4.67.1)
# Requirement already satisfied: requests in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torchtext==0.17.2) (2.32.5)
# Requirement already satisfied: torch==2.2.2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torchtext==0.17.2) (2.2.2)
# Requirement already satisfied: numpy in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torchtext==0.17.2) (1.26.4)
# Requirement already satisfied: filelock in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2->torchtext==0.17.2) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2->torchtext==0.17.2) (4.15.0)
# Requirement already satisfied: sympy in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2->torchtext==0.17.2) (1.14.0)
# Requirement already satisfied: networkx in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2->torchtext==0.17.2) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2->torchtext==0.17.2) (3.1.6)
# Requirement already satisfied: fsspec in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from torch==2.2.2->torchtext==0.17.2) (2026.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from jinja2->torch==2.2.2->torchtext==0.17.2) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests->torchtext==0.17.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests->torchtext==0.17.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests->torchtext==0.17.2) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests->torchtext==0.17.2) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from sympy->torch==2.2.2->torchtext==0.17.2) (1.3.0)
# Downloading torchtext-0.17.2-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.2 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: torchtext
# Successfully installed torchtext-0.17.2
# Collecting numpy==1.26.0
#   Downloading numpy-1.26.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (99 kB)
# Downloading numpy-1.26.0-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 31.1 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.4.1 requires numpy>=1.26.2; python_version < "3.13", but you have numpy 1.26.0 which is incompatible.
# crewai 1.9.3 requires mcp~=1.23.1, but you have mcp 1.15.0 which is incompatible.
# crewai 1.9.3 requires tokenizers~=0.20.3, but you have tokenizers 0.19.1 which is incompatible.
# llama-index-llms-openai 0.6.15 requires openai<3,>=1.108.1, but you have openai 1.83.0 which is incompatible.
# scipy 1.17.0 requires numpy<2.7,>=1.26.4, but you have numpy 1.26.0 which is incompatible.
# Successfully installed numpy-1.26.0

# %%
import nltk
nltk.download("punkt")
nltk.download("punkt_tab")
import spacy
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.util import ngrams
from transformers import BertTokenizer
from transformers import XLNetTokenizer
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package punkt to /Users/anirudh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/anirudh/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
text = "This is a sample sentence for word tokenization"
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', 'for', 'word', 'tokenization']

# %%
#This showcases word_tokenize from nltk library

text = "I couldn't help the dog. Can't you do it? Don't be afraid if you are."
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['I', 'could', "n't", 'help', 'the', 'dog', '.', 'Ca', "n't", 'you', 'do', 'it', '?', 'Do', "n't", 'be', 'afraid', 'if', 'you', 'are', '.']

# %%
# This showcases the use of the 'spaCy' tokenizer with torchtext's get_tokenizer function
text = "I couldn't help the dog. Can't you do it? Don't be afraid if you are."
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)
token_list = [token.text for token in doc]
print(f"Token list:{token_list}")
# Showing token details
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Token list:['I', 'could', "n't", 'help', 'the', 'dog', '.', 'Ca', "n't", 'you', 'do', 'it', '?', 'Do', "n't", 'be', 'afraid', 'if', 'you', 'are', '.']
# I PRON nsubj
# could AUX aux
# n't PART neg
# help VERB ROOT
# the DET det
# dog NOUN dobj
# . PUNCT punct
# Ca AUX aux
# n't PART neg
# you PRON nsubj
# do VERB ROOT
# it PRON dobj
# ? PUNCT punct
# Do AUX aux
# n't PART neg
# be AUX ROOT
# afraid ADJ acomp
# if SCONJ mark
# you PRON nsubj
# are AUX advcl
# . PUNCT punct

# %%
text = "Unicorns are real. I saw a unicorn yesterday."
token = word_tokenize(text)
print(token)
# Out:
# ['Unicorns', 'are', 'real', '.', 'I', 'saw', 'a', 'unicorn', 'yesterday', '.']

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
tokenizer.tokenize("IBM taught me tokenization.")
# Out:
# ['ibm', 'taught', 'me', 'token', '##ization', '.']

# %%
tokenizer = XLNetTokenizer.from_pretrained("xlnet-base-cased")
tokenizer.tokenize("IBM taught me tokenization.")
# Out:
# ['▁IBM', '▁taught', '▁me', '▁token', 'ization', '.']

# %%
dataset = [
    (1,"Introduction to NLP"),
    (2,"Basics of PyTorch"),
    (1,"NLP Techniques for Text Classification"),
    (3,"Named Entity Recognition with PyTorch"),
    (3,"Sentiment Analysis using PyTorch"),
    (3,"Machine Translation with PyTorch"),
    (1," NLP Named Entity,Sentiment Analysis,Machine Translation "),
    (1," Machine Translation with NLP "),
    (1," Named Entity vs Sentiment Analysis  NLP ")]

# %%
tokenizer = get_tokenizer("basic_english")
tokenizer(dataset[0][1])
# Out:
# ['introduction', 'to', 'nlp']

# %%
def yield_tokens(data_iter):
    for  _,text in data_iter:
        yield tokenizer(text)

# %%
my_iterator = yield_tokens(dataset)

# %%
next(my_iterator)
# Out:
# ['introduction', 'to', 'nlp']

# %%
vocab = build_vocab_from_iterator(yield_tokens(dataset), specials = ["<unk>"])
vocab.set_default_index(vocab["<unk>"])

# %%
def get_tokenized_sentence_and_indices(iterator):
    tokenized_sentence = next(iterator)  # Get the next tokenized sentence
    token_indices = [vocab[token] for token in tokenized_sentence]  # Get token indices
    return tokenized_sentence, token_indices

tokenized_sentence, token_indices = get_tokenized_sentence_and_indices(my_iterator)
next(my_iterator)

print("Tokenized Sentence:", tokenized_sentence)
print("Token Indices:", token_indices)
# Out:
# Tokenized Sentence: ['basics', 'of', 'pytorch']
# Token Indices: [11, 15, 2]

# %%
lines = ["IBM taught me tokenization", 
         "Special tokenizers are ready and they will blow your mind", 
         "just saying hi!"]

special_symbols = ['<unk>', '<pad>', '<bos>', '<eos>']

tokenizer_en = get_tokenizer('spacy', language='en_core_web_sm')

tokens = []
max_length = 0

for line in lines:
    tokenized_line = tokenizer_en(line)
    tokenized_line = ['<bos>'] + tokenized_line + ['<eos>']
    tokens.append(tokenized_line)
    max_length = max(max_length, len(tokenized_line))

for i in range(len(tokens)):
    tokens[i] = tokens[i] + ['<pad>'] * (max_length - len(tokens[i]))

print("Lines after adding special tokens:\n", tokens)

# Build vocabulary without unk_init
vocab = build_vocab_from_iterator(tokens, specials=['<unk>'])
vocab.set_default_index(vocab["<unk>"])

# Vocabulary and Token Ids
print("Vocabulary:", vocab.get_itos())
print("Token IDs for 'tokenization':", vocab.get_stoi())
# Out:
# Lines after adding special tokens:
#  [['<bos>', 'IBM', 'taught', 'me', 'tokenization', '<eos>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>'], ['<bos>', 'Special', 'tokenizers', 'are', 'ready', 'and', 'they', 'will', 'blow', 'your', 'mind', '<eos>'], ['<bos>', 'just', 'saying', 'hi', '!', '<eos>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']]
# Vocabulary: ['<unk>', '<pad>', '<bos>', '<eos>', '!', 'IBM', 'Special', 'and', 'are', 'blow', 'hi', 'just', 'me', 'mind', 'ready', 'saying', 'taught', 'they', 'tokenization', 'tokenizers', 'will', 'your']
# Token IDs for 'tokenization': {'your': 21, 'will': 20, 'tokenizers': 19, 'taught': 16, 'saying': 15, 'mind': 13, 'blow': 9, 'are': 8, 'Special': 6, 'IBM': 5, '!': 4, 'tokenization': 18, 'ready': 14, '<eos>': 3, 'they': 17, 'hi': 10, 'and': 7, '<bos>': 2, 'me': 12, 'just': 11, '<pad>': 1, '<unk>': 0}

# %%
new_line = "I elarned about embeddings and attention"
tokenized_new_line = tokenizer_en(new_line)
tokenized_new_line = ["<bos>"] + tokenized_new_line + ["<eos>"]
new_line_padded = tokenized_new_line + ['<pad>'] * (max_length - len(tokenized_new_line))
new_line_ids = [vocab[token] if token in vocab else vocab["<unk>"] for token in new_line_padded]
print(f"Token ids for new line:{new_line_ids}")
# Out:
# Token ids for new line:[2, 0, 0, 0, 0, 7, 0, 3, 1, 1, 1, 1]
