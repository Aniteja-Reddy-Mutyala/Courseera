# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %%
import requests 
def download_file(url, file_name): 
    response = requests.get(url) 
    if response.status_code == 200 : 
        with open(file_name , "wb") as f: 
            f.write(response.content)

# %%
#you will need to download the dataset; 
download_file('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/module_5_auto.csv','module_5_auto.csv')

# %%
df = pd.read_csv("module_5_auto.csv", header = 0)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  symboling  normalized-losses         make  \
# 0             0           0          3                122  alfa-romero
# 1             1           1          3                122  alfa-romero
# 2             2           2          1                122  alfa-romero
# 3             3           3          2                164         audi
# 4             4           4          2                164         audi
#
#   aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# 0        std          two  convertible          rwd           front  ...
# 1        std          two  convertible          rwd           front  ...
# 2        std          two    hatchback          rwd           front  ...
# 3        std         four        sedan          fwd           front  ...
# 4        std         four        sedan          4wd           front  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price  \
# 0                9.0       111.0    5000.0        21           27  13495.0
# 1                9.0       111.0    5000.0        21           27  16500.0
# 2                9.0       154.0    5000.0        19           26  16500.0
# 3               10.0       102.0    5500.0        24           30  13950.0
# 4                8.0       115.0    5500.0        18           22  17450.0
#
#   city-L/100km  horsepower-binned diesel  gas
# 0    11.190476             Medium      0    1
# 1    11.190476             Medium      0    1
# 2    12.368421             Medium      0    1
# 3     9.791667             Medium      0    1
# 4    13.055556             Medium      0    1
#
# [5 rows x 31 columns]

# %%
df=df._get_numeric_data()
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  symboling  normalized-losses  wheel-base  \
# 0             0           0          3                122        88.6
# 1             1           1          3                122        88.6
# 2             2           2          1                122        94.5
# 3             3           3          2                164        99.8
# 4             4           4          2                164        99.4
#
#      length     width  height  curb-weight  engine-size  ...  stroke  \
# 0  0.811148  0.890278    48.8         2548          130  ...    2.68
# 1  0.811148  0.890278    48.8         2548          130  ...    2.68
# 2  0.822681  0.909722    52.4         2823          152  ...    3.47
# 3  0.848630  0.919444    54.3         2337          109  ...    3.40
# 4  0.848630  0.922222    54.3         2824          136  ...    3.40
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price  \
# 0                9.0       111.0    5000.0        21           27  13495.0
# 1                9.0       111.0    5000.0        21           27  16500.0
# 2                9.0       154.0    5000.0        19           26  16500.0
# 3               10.0       102.0    5500.0        24           30  13950.0
# 4                8.0       115.0    5500.0        18           22  17450.0
#
#    city-L/100km  diesel  gas
# 0     11.190476       0    1
# 1     11.190476       0    1
# 2     12.368421       0    1
# 3      9.791667       0    1
# 4     13.055556       0    1
#
# [5 rows x 21 columns]

# %%
df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1, inplace=True)

# Let's take a look at the updated DataFrame
df.head()
# Out:
#    symboling  normalized-losses  wheel-base    length     width  height  \
# 0          3                122        88.6  0.811148  0.890278    48.8
# 1          3                122        88.6  0.811148  0.890278    48.8
# 2          1                122        94.5  0.822681  0.909722    52.4
# 3          2                164        99.8  0.848630  0.919444    54.3
# 4          2                164        99.4  0.848630  0.922222    54.3
#
#    curb-weight  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0         2548          130  3.47    2.68                9.0       111.0
# 1         2548          130  3.47    2.68                9.0       111.0
# 2         2823          152  2.68    3.47                9.0       154.0
# 3         2337          109  3.19    3.40               10.0       102.0
# 4         2824          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price  city-L/100km  diesel  gas
# 0    5000.0        21           27  13495.0     11.190476       0    1
# 1    5000.0        21           27  16500.0     11.190476       0    1
# 2    5000.0        19           26  16500.0     12.368421       0    1
# 3    5500.0        24           30  13950.0      9.791667       0    1
# 4    5500.0        18           22  17450.0     13.055556       0    1

# %%
# !pip install micropip
import micropip
await micropip.install(['ipywidgets'], keep_going=True)
import ipywidgets
from ipywidgets import interact, interactive, fixed, interact
# Out:
# Requirement already satisfied: micropip in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (0.7.2)
# Requirement already satisfied: packaging>=23.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from micropip) (25.0)

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title): 
    width = 12 
    height = 10
    plt.figure(figsize = (width, height))
    ax1 = sns.kdeplot(RedFunction, color = "r", label = RedName)
    ax2 = sns.kdeplot(BlueFunction, color = "b", label = BlueName, ax = ax1)
    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')
    plt.show()
    plt.close()

# %%
def PollyPlot(xtrain, xtest, y_train, y_test, lr, poly_transform): 
    width = 12 
    height = 10 
    plt.figure(figsize = (width, height))
    xmax = max([xtrain.values.max(), xtest.values.max()])
    xmin = min ([xtrain.values.min(), xtest.values.min()])
    x = np.arange(xmin, xmax, 0.1)
    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()

# %%
y_data = df["price"]

# %%
x_data = df.drop("price", axis = 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.2, random_state= 42)
print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 41
# number of training samples: 160

# %%
from sklearn.linear_model import LinearRegression
lre = LinearRegression()

# %%
lre.fit(x_train[["horsepower"]], y_train)
# Out:
# LinearRegression()

# %%
lre.score(x_test[["horsepower"]],y_test)
# Out:
# 0.6232540189833462

# %%
lre.score(x_train[["horsepower"]],y_train)
# Out:
# 0.6423115922166709

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.4, random_state = 42)

# %%
lre.fit(x_train[["horsepower"]],y_train)
# Out:
# LinearRegression()

# %%
lre.score(x_test[["horsepower"]], y_test)
# Out:
# 0.650792491230779

# %%
lre.score(x_train[["horsepower"]],y_train)
# Out:
# 0.6459200542246597

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

# %%
Rcross = cross_val_score(lre, x_data[["horsepower"]], y_data, cv = 4) 
Rcross
# Out:
# array([0.7746232 , 0.51716687, 0.74785353, 0.04839605])

# %%
print("The mean of the folds are", Rcross.mean(), "and the standard deviation is" , Rcross.std())
# Out:
# The mean of the folds are 0.5220099150421196 and the standard deviation is 0.2911839444756023

# %%
-1 * cross_val_score(lre,x_data[['horsepower']], y_data,cv=4,scoring='neg_mean_squared_error')
# Out:
# array([20254142.84026702, 43745493.2650517 , 12539630.34014929,
#        17561927.72247588])

# %%
yhat = cross_val_predict(lre,x_data[['horsepower']], y_data,cv=4)
yhat[0:5]
# Out:
# array([14141.63807508, 14141.63807508, 20814.29423473, 12745.03562306,
#        14762.35027598])

# %%
lr = LinearRegression()
lr.fit(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_train)
# Out:
# LinearRegression()

# %%
yhat_train = lr.predict(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_train[0:5]
# Out:
# array([11274.02005462, 40384.06905149, 17262.7209989 , 16132.26675255,
#        11385.68674021])

# %%
yhat_test = lr.predict(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_test[0:5]
# Out:
# array([ 7064.81712019, 25811.82207494,  6007.63274599,  7984.90306957,
#        13339.85256871])

# %%
Title = 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_train, yhat_train, "Actual Values (Train)", "Predicted Values (Train)", Title)

# %%
Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",Title)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.45, random_state=0)

# %%
pr = PolynomialFeatures(degree=5)
x_train_pr = pr.fit_transform(x_train[['horsepower']])
x_test_pr = pr.fit_transform(x_test[['horsepower']])
pr
# Out:
# PolynomialFeatures(degree=5)

# %%
poly = LinearRegression()
poly.fit(x_train_pr, y_train)
# Out:
# LinearRegression()

# %%
yhat = poly.predict(x_test_pr)
yhat[0:5]
# Out:
# array([ 6728.72239532,  7308.04778705, 12213.80433217, 18893.15624328,
#        19995.84735794])

# %%
print("Predicted values:", yhat[0:4])
print("True values:", y_test[0:4].values)
# Out:
# Predicted values: [ 6728.72239532  7308.04778705 12213.80433217 18893.15624328]
# True values: [ 6295. 10698. 13860. 13499.]

# %%
PollyPlot(x_train['horsepower'], x_test['horsepower'], y_train, y_test, poly,pr)

# %%
poly.score(x_train_pr, y_train)
# Out:
# 0.5567716902497449

# %%
poly.score(x_test_pr, y_test)
# Out:
# -29.871481097601183

# %%
Rsqu_test = []

order = [1, 2, 3, 4]
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[['horsepower']])
    
    x_test_pr = pr.fit_transform(x_test[['horsepower']])    
    
    lr.fit(x_train_pr, y_train)
    
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
plt.text(3, 0.75, 'Maximum R^2 ')
# Out:
# Text(3, 0.75, 'Maximum R^2 ')

# %%
def f(order, test_data):
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=test_data, random_state=0)
    pr = PolynomialFeatures(degree=order)
    x_train_pr = pr.fit_transform(x_train[['horsepower']])
    x_test_pr = pr.fit_transform(x_test[['horsepower']])
    poly = LinearRegression()
    poly.fit(x_train_pr,y_train)
    PollyPlot(x_train['horsepower'], x_test['horsepower'], y_train, y_test, poly,pr)

# %%
interact(f, order=(0, 6, 1), test_data=(0.05, 0.95, 0.05))
# Out:
# interactive(children=(IntSlider(value=3, description='order', max=6), FloatSlider(value=0.45, description='tes…
# <function __main__.f(order, test_data)>

# %%
from sklearn.linear_model import Ridge

# %%
RidgeModel = Ridge(alpha = 1)

# %%
RidgeModel.fit(x_train_pr, y_train)
# Out:
# /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.1718903888764584e-19.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Ridge(alpha=1)

# %%
yhat = RidgeModel.predict(x_test_pr)
yhat[0:5]
# Out:
# array([ 7439.15485492,  7826.49627157, 11284.32208136, 19953.96351143,
#        20506.60231942])

# %%
print('predicted:', yhat[0:4])
print('test set :', y_test[0:4].values)
# Out:
# predicted: [ 7439.15485492  7826.49627157 11284.32208136 19953.96351143]
# test set : [ 6295. 10698. 13860. 13499.]

# %%
from tqdm import tqdm

Rsqu_test = []
Rsqu_train = []
dummy1 = []
Alpha = 10 * np.array(range(0,1000))
pbar = tqdm(Alpha)

for alpha in pbar:
    RigeModel = Ridge(alpha=alpha) 
    RigeModel.fit(x_train_pr, y_train)
    test_score, train_score = RigeModel.score(x_test_pr, y_test), RigeModel.score(x_train_pr, y_train)
    
    pbar.set_postfix({"Test Score": test_score, "Train Score": train_score})

    Rsqu_test.append(test_score)
    Rsqu_train.append(train_score)
# Out:
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.406, Train Score=0.535]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.1718903888764583e-18.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|              | 0/1000 [00:00<?, ?it/s, Test Score=0.58, Train Score=0.535]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.3437807777529166e-18.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.631, Train Score=0.535]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 3.515671166629375e-18.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.654, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 4.687561555505833e-18.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.667, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 5.8594519443822916e-18.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.675, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 7.031342333258751e-18.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.681, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 8.203232722135208e-18.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.685, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 9.375123111011666e-18.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.688, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.0547013499888125e-17.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.691, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.1718903888764583e-17.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.693, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.289079427764104e-17.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.694, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.40626846665175e-17.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.696, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.5234575055393953e-17.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.697, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.6406465444270416e-17.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.698, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.7578355833146876e-17.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.699, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.8750246222023333e-17.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|             | 0/1000 [00:00<?, ?it/s, Test Score=0.699, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.9922136610899796e-17.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   0%|               | 0/1000 [00:00<?, ?it/s, Test Score=0.7, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.109402699977625e-17.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#
-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▎ | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.709, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.5181976287871665e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▎ | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.709, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.5297643860383625e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▎ | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.709, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.5413311436653398e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▎ | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.709, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.5528979016681582e-16.
# ...
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.7148325531827528e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.726399316824991e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.7379660808426732e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.7495328452365604e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.7610996100068438e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.7726663751527171e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.7842331406745034e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.795799906572164e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.8073666728458522e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.8189334394951904e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.8305002065209383e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.8420669739222557e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.8536337416998634e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.86520050985277e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.8767672783821141e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.8883340472870485e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.8999008165685737e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.9114675862253199e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.9230343562580862e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.934601126666831e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.9461678974518428e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.957734668612645e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.969301440148683e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.980868212061679e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  13%|▍  | 127/1000 [00:00<00:01, 438.44it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 1.9924349843497355e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.0040017570141706e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.015568530054273e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.027135303470308e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.0387020772627736e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.0502688514303058e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.0618356259742297e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.073402400894193e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.0849691761895495e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.096535951860829e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.1081027279082108e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.1196695043319708e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.1312362811309539e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.1428030583061196e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.1543698358574287e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.1659366137839206e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.1775033920866703e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.1890701707655461e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.2006369498193954e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#  17%|▌  | 172/1000 [00:00<00:01, 441.22it/s, Test Score=0.71, Train Score=0.534]/Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:228: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 2.212203729250407e-16.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# 100%|█| 1000/1000 [00:04<00:00, 208.66it/s, Test Score=0.711, Train Score=0.534]

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))

plt.plot(Alpha,Rsqu_test, label='validation data  ')
plt.plot(Alpha,Rsqu_train, 'r', label='training Data ')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.legend()

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters1= [{'alpha': [0.001,0.1,1, 10, 100, 1000, 10000, 100000, 100000]}]
parameters1
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

# %%
RR=Ridge()
RR
# Out:
# Ridge()

# %%
Grid1 = GridSearchCV(RR, parameters1,cv=4)

# %%
Grid1.fit(x_data[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_data)
# Out:
# GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid=[{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000,
#                                     100000]}])

# %%
BestRR=Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=10000)

# %%
BestRR.score(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_test)
# Out:
# 0.8411649831036152
