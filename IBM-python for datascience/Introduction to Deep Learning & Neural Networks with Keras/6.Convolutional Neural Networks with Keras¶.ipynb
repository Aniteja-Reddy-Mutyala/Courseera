# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Input, Flatten, MaxPooling2D
from keras.utils import to_categorical

# %%
#import data
from keras.datasets import mnist
#load data 
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#reshape to [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype("float32")
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype("float32")

# %%
X_train = X_train / 255 # normalize training data
X_test = X_test / 255 # normalize test data

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories

# %%
num_classes
# Out:
# 10

# %%
def convolutional_model(): 
    #Create model 
    model = Sequential() 
    model.add(Input(shape = (28, 28, 1)))
    model.add(Conv2D(16, (5,5),strides = (1, 1),activation = "relu"))
    model.add(MaxPooling2D(pool_size = (2, 2),strides = (2, 2))) 
    model.add(Flatten()) 
    model.add(Dense(100, activation = "relu"))
    model.add(Dense(num_classes, activation = "softmax"))

    #compile model 
    model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics= ["accuracy"])
    return model

# %%
#build the model 
model = convolutional_model() 
model.fit(X_train , y_train , validation_data = (X_test, y_test), epochs = 10, batch_size= 200, verbose = 2)
#Evaluate the model 
scores = model.evaluate(X_test, y_test) 
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 19s - 63ms/step - accuracy: 0.9119 - loss: 0.3005 - val_accuracy: 0.9667 - val_loss: 0.1093
# Epoch 2/10
# 300/300 - 20s - 68ms/step - accuracy: 0.9732 - loss: 0.0922 - val_accuracy: 0.9776 - val_loss: 0.0700
# Epoch 3/10
# 300/300 - 18s - 60ms/step - accuracy: 0.9817 - loss: 0.0625 - val_accuracy: 0.9833 - val_loss: 0.0531
# Epoch 4/10
# 300/300 - 21s - 69ms/step - accuracy: 0.9862 - loss: 0.0469 - val_accuracy: 0.9831 - val_loss: 0.0500
# Epoch 5/10
# 300/300 - 21s - 70ms/step - accuracy: 0.9889 - loss: 0.0371 - val_accuracy: 0.9854 - val_loss: 0.0447
# Epoch 6/10
# 300/300 - 21s - 72ms/step - accuracy: 0.9904 - loss: 0.0315 - val_accuracy: 0.9870 - val_loss: 0.0383
# Epoch 7/10
# 300/300 - 37s - 124ms/step - accuracy: 0.9915 - loss: 0.0271 - val_accuracy: 0.9873 - val_loss: 0.0366
# Epoch 8/10
# 300/300 - 18s - 60ms/step - accuracy: 0.9938 - loss: 0.0212 - val_accuracy: 0.9880 - val_loss: 0.0381
# Epoch 9/10
# 300/300 - 18s - 58ms/step - accuracy: 0.9943 - loss: 0.0191 - val_accuracy: 0.9866 - val_loss: 0.0400
# Epoch 10/10
# 300/300 - 17s - 58ms/step - accuracy: 0.9952 - loss: 0.0158 - val_accuracy: 0.9894 - val_loss: 0.0365
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9894 - loss: 0.0365
# Accuracy: 0.9894000291824341
#  Error: 1.0599970817565918

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 21s - 71ms/step - accuracy: 0.8717 - loss: 0.4507 - val_accuracy: 0.9659 - val_loss: 0.1160
# Epoch 2/10
# 300/300 - 20s - 66ms/step - accuracy: 0.9673 - loss: 0.1086 - val_accuracy: 0.9780 - val_loss: 0.0736
# Epoch 3/10
# 300/300 - 21s - 68ms/step - accuracy: 0.9755 - loss: 0.0804 - val_accuracy: 0.9820 - val_loss: 0.0581
# Epoch 4/10
# 300/300 - 21s - 70ms/step - accuracy: 0.9806 - loss: 0.0646 - val_accuracy: 0.9829 - val_loss: 0.0520
# Epoch 5/10
# 300/300 - 20s - 66ms/step - accuracy: 0.9829 - loss: 0.0546 - val_accuracy: 0.9837 - val_loss: 0.0474
# Epoch 6/10
# 300/300 - 20s - 65ms/step - accuracy: 0.9850 - loss: 0.0491 - val_accuracy: 0.9879 - val_loss: 0.0402
# Epoch 7/10
# 300/300 - 21s - 68ms/step - accuracy: 0.9871 - loss: 0.0418 - val_accuracy: 0.9879 - val_loss: 0.0397
# Epoch 8/10
# 300/300 - 20s - 65ms/step - accuracy: 0.9884 - loss: 0.0371 - val_accuracy: 0.9877 - val_loss: 0.0352
# Epoch 9/10
# 300/300 - 20s - 68ms/step - accuracy: 0.9890 - loss: 0.0342 - val_accuracy: 0.9891 - val_loss: 0.0331
# Epoch 10/10
# 300/300 - 20s - 67ms/step - accuracy: 0.9904 - loss: 0.0305 - val_accuracy: 0.9855 - val_loss: 0.0418
# Accuracy: 0.9854999780654907
#  Error: 1.4500021934509277

# %%
model = convolutional_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 59/59 - 22s - 377ms/step - accuracy: 0.6432 - loss: 1.2983 - val_accuracy: 0.8708 - val_loss: 0.4452
# Epoch 2/10
# 59/59 - 40s - 679ms/step - accuracy: 0.9039 - loss: 0.3298 - val_accuracy: 0.9363 - val_loss: 0.2322
# Epoch 3/10
# 59/59 - 21s - 355ms/step - accuracy: 0.9385 - loss: 0.2104 - val_accuracy: 0.9540 - val_loss: 0.1622
# Epoch 4/10
# 59/59 - 20s - 334ms/step - accuracy: 0.9526 - loss: 0.1611 - val_accuracy: 0.9619 - val_loss: 0.1304
# Epoch 5/10
# 59/59 - 21s - 359ms/step - accuracy: 0.9606 - loss: 0.1324 - val_accuracy: 0.9681 - val_loss: 0.1097
# Epoch 6/10
# 59/59 - 19s - 317ms/step - accuracy: 0.9675 - loss: 0.1121 - val_accuracy: 0.9734 - val_loss: 0.0921
# Epoch 7/10
# 59/59 - 19s - 322ms/step - accuracy: 0.9707 - loss: 0.0987 - val_accuracy: 0.9744 - val_loss: 0.0841
# Epoch 8/10
# 59/59 - 19s - 327ms/step - accuracy: 0.9741 - loss: 0.0865 - val_accuracy: 0.9776 - val_loss: 0.0738
# Epoch 9/10
# 59/59 - 21s - 351ms/step - accuracy: 0.9765 - loss: 0.0787 - val_accuracy: 0.9794 - val_loss: 0.0692
# Epoch 10/10
# 59/59 - 20s - 337ms/step - accuracy: 0.9792 - loss: 0.0715 - val_accuracy: 0.9797 - val_loss: 0.0661
# Accuracy: 0.9797000288963318
#  Error: 2.0299971103668213

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/25
# 59/59 - 20s - 346ms/step - accuracy: 0.6619 - loss: 1.2539 - val_accuracy: 0.8894 - val_loss: 0.3948
# Epoch 2/25
# 59/59 - 22s - 365ms/step - accuracy: 0.9063 - loss: 0.3175 - val_accuracy: 0.9340 - val_loss: 0.2347
# Epoch 3/25
# 59/59 - 19s - 325ms/step - accuracy: 0.9372 - loss: 0.2110 - val_accuracy: 0.9529 - val_loss: 0.1628
# Epoch 4/25
# 59/59 - 19s - 325ms/step - accuracy: 0.9541 - loss: 0.1541 - val_accuracy: 0.9658 - val_loss: 0.1248
# Epoch 5/25
# 59/59 - 20s - 347ms/step - accuracy: 0.9638 - loss: 0.1218 - val_accuracy: 0.9715 - val_loss: 0.1019
# Epoch 6/25
# 59/59 - 20s - 345ms/step - accuracy: 0.9692 - loss: 0.1030 - val_accuracy: 0.9749 - val_loss: 0.0856
# Epoch 7/25
# 59/59 - 20s - 347ms/step - accuracy: 0.9732 - loss: 0.0891 - val_accuracy: 0.9765 - val_loss: 0.0748
# Epoch 8/25
# 59/59 - 20s - 342ms/step - accuracy: 0.9765 - loss: 0.0786 - val_accuracy: 0.9761 - val_loss: 0.0741
# Epoch 9/25
# 59/59 - 20s - 345ms/step - accuracy: 0.9791 - loss: 0.0715 - val_accuracy: 0.9809 - val_loss: 0.0614
# Epoch 10/25
# 59/59 - 19s - 323ms/step - accuracy: 0.9806 - loss: 0.0651 - val_accuracy: 0.9815 - val_loss: 0.0573
# Epoch 11/25
# 59/59 - 21s - 353ms/step - accuracy: 0.9816 - loss: 0.0619 - val_accuracy: 0.9827 - val_loss: 0.0533
# Epoch 12/25
# 59/59 - 20s - 342ms/step - accuracy: 0.9828 - loss: 0.0566 - val_accuracy: 0.9827 - val_loss: 0.0538
# Epoch 13/25
# 59/59 - 21s - 348ms/step - accuracy: 0.9841 - loss: 0.0541 - val_accuracy: 0.9839 - val_loss: 0.0480
# Epoch 14/25
# 59/59 - 21s - 348ms/step - accuracy: 0.9847 - loss: 0.0511 - val_accuracy: 0.9853 - val_loss: 0.0461
# Epoch 15/25
# 59/59 - 19s - 322ms/step - accuracy: 0.9855 - loss: 0.0477 - val_accuracy: 0.9849 - val_loss: 0.0472
# Epoch 16/25
# 59/59 - 21s - 350ms/step - accuracy: 0.9860 - loss: 0.0465 - val_accuracy: 0.9860 - val_loss: 0.0435
# Epoch 17/25
# 59/59 - 19s - 324ms/step - accuracy: 0.9864 - loss: 0.0446 - val_accuracy: 0.9856 - val_loss: 0.0478
# Epoch 18/25
# 59/59 - 20s - 347ms/step - accuracy: 0.9873 - loss: 0.0424 - val_accuracy: 0.9862 - val_loss: 0.0438
# Epoch 19/25
# 59/59 - 20s - 338ms/step - accuracy: 0.9876 - loss: 0.0408 - val_accuracy: 0.9869 - val_loss: 0.0425
# Epoch 20/25
# 59/59 - 22s - 371ms/step - accuracy: 0.9875 - loss: 0.0401 - val_accuracy: 0.9868 - val_loss: 0.0412
# Epoch 21/25
# 59/59 - 20s - 331ms/step - accuracy: 0.9887 - loss: 0.0377 - val_accuracy: 0.9879 - val_loss: 0.0385
# Epoch 22/25
# 59/59 - 20s - 347ms/step - accuracy: 0.9891 - loss: 0.0363 - val_accuracy: 0.9877 - val_loss: 0.0396
# Epoch 23/25
# 59/59 - 19s - 328ms/step - accuracy: 0.9891 - loss: 0.0352 - val_accuracy: 0.9862 - val_loss: 0.0430
# Epoch 24/25
# 59/59 - 20s - 346ms/step - accuracy: 0.9897 - loss: 0.0338 - val_accuracy: 0.9875 - val_loss: 0.0396
# Epoch 25/25
# 59/59 - 19s - 322ms/step - accuracy: 0.9899 - loss: 0.0319 - val_accuracy: 0.9891 - val_loss: 0.0358
# Accuracy: 0.9890999794006348
#  Error: 1.0900020599365234
