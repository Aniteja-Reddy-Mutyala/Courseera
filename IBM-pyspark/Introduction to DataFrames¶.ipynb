# %%
import findspark
findspark.init()

# %%
import pandas as pd
from pyspark.sql import SparkSession
from pyspark import SparkConf,SparkContext

# %%
#creating a spark session
spark = SparkSession \
        .builder \
        .appName("Python spark dataframes basic example") \
        .config("spark.some.config.option" ,"some-value") \
        .getOrCreate()
if "spark" in locals() and isinstance(spark, SparkSession):
    print("Spark session is active and running")
else:
    print("Spark session isn't active.Please create a new spark session.")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/02/16 21:26:56 WARN Utils: Your hostname, Anirudhs-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 192.168.4.33 instead (on interface en0)
# 26/02/16 21:26:56 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/16 21:26:57 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/02/16 21:26:58 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/02/16 21:26:58 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# Spark session is active and running

# %%
# Read the file using `read_csv` function in pandas
mtcars = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0225EN-SkillsNetwork/labs/data/mtcars.csv')

# %%
mtcars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
sdf = spark.createDataFrame(mtcars)
sdf.show(5)
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# |       Unnamed: 0| mpg|cyl| disp| hp|drat|   wt| qsec| vs| am|gear|carb|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# |        Mazda RX4|21.0|  6|160.0|110| 3.9| 2.62|16.46|  0|  1|   4|   4|
# |    Mazda RX4 Wag|21.0|  6|160.0|110| 3.9|2.875|17.02|  0|  1|   4|   4|
# |       Datsun 710|22.8|  4|108.0| 93|3.85| 2.32|18.61|  1|  1|   4|   1|
# |   Hornet 4 Drive|21.4|  6|258.0|110|3.08|3.215|19.44|  1|  0|   3|   1|
# |Hornet Sportabout|18.7|  8|360.0|175|3.15| 3.44|17.02|  0|  0|   3|   2|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# only showing top 5 rows

# %%
sdf.printSchema()
# Out:
# root
#  |-- Unnamed: 0: string (nullable = true)
#  |-- mpg: double (nullable = true)
#  |-- cyl: long (nullable = true)
#  |-- disp: double (nullable = true)
#  |-- hp: long (nullable = true)
#  |-- drat: double (nullable = true)
#  |-- wt: double (nullable = true)
#  |-- qsec: double (nullable = true)
#  |-- vs: long (nullable = true)
#  |-- am: long (nullable = true)
#  |-- gear: long (nullable = true)
#  |-- carb: long (nullable = true)

# %%
sdf.select("mpg").show(5)
# Out:
# +----+
# | mpg|
# +----+
# |21.0|
# |21.0|
# |22.8|
# |21.4|
# |18.7|
# +----+
# only showing top 5 rows

# %%
sdf.filter(sdf["mpg"] < 18).show(5)
# Out:
# +-----------+----+---+-----+---+----+----+-----+---+---+----+----+
# | Unnamed: 0| mpg|cyl| disp| hp|drat|  wt| qsec| vs| am|gear|carb|
# +-----------+----+---+-----+---+----+----+-----+---+---+----+----+
# | Duster 360|14.3|  8|360.0|245|3.21|3.57|15.84|  0|  0|   3|   4|
# |  Merc 280C|17.8|  6|167.6|123|3.92|3.44| 18.9|  1|  0|   4|   4|
# | Merc 450SE|16.4|  8|275.8|180|3.07|4.07| 17.4|  0|  0|   3|   3|
# | Merc 450SL|17.3|  8|275.8|180|3.07|3.73| 17.6|  0|  0|   3|   3|
# |Merc 450SLC|15.2|  8|275.8|180|3.07|3.78| 18.0|  0|  0|   3|   3|
# +-----------+----+---+-----+---+----+----+-----+---+---+----+----+
# only showing top 5 rows

# %%
sdf.withColumn("wtTon", sdf["wt"]*0.45).show(5)
# Out:
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+-------+
# |       Unnamed: 0| mpg|cyl| disp| hp|drat|   wt| qsec| vs| am|gear|carb|  wtTon|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+-------+
# |        Mazda RX4|21.0|  6|160.0|110| 3.9| 2.62|16.46|  0|  1|   4|   4|  1.179|
# |    Mazda RX4 Wag|21.0|  6|160.0|110| 3.9|2.875|17.02|  0|  1|   4|   4|1.29375|
# |       Datsun 710|22.8|  4|108.0| 93|3.85| 2.32|18.61|  1|  1|   4|   1|  1.044|
# |   Hornet 4 Drive|21.4|  6|258.0|110|3.08|3.215|19.44|  1|  0|   3|   1|1.44675|
# |Hornet Sportabout|18.7|  8|360.0|175|3.15| 3.44|17.02|  0|  0|   3|   2|  1.548|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+-------+
# only showing top 5 rows

# %%
sdf.withColumnRenamed("vs","versus").show(5)
# Out:
# +-----------------+----+---+-----+---+----+-----+-----+------+---+----+----+
# |       Unnamed: 0| mpg|cyl| disp| hp|drat|   wt| qsec|versus| am|gear|carb|
# +-----------------+----+---+-----+---+----+-----+-----+------+---+----+----+
# |        Mazda RX4|21.0|  6|160.0|110| 3.9| 2.62|16.46|     0|  1|   4|   4|
# |    Mazda RX4 Wag|21.0|  6|160.0|110| 3.9|2.875|17.02|     0|  1|   4|   4|
# |       Datsun 710|22.8|  4|108.0| 93|3.85| 2.32|18.61|     1|  1|   4|   1|
# |   Hornet 4 Drive|21.4|  6|258.0|110|3.08|3.215|19.44|     1|  0|   3|   1|
# |Hornet Sportabout|18.7|  8|360.0|175|3.15| 3.44|17.02|     0|  0|   3|   2|
# +-----------------+----+---+-----+---+----+-----+-----+------+---+----+----+
# only showing top 5 rows

# %%
sdf.where(sdf["mpg"]< 18).show(5)
# Out:
# +-----------+----+---+-----+---+----+----+-----+---+---+----+----+
# | Unnamed: 0| mpg|cyl| disp| hp|drat|  wt| qsec| vs| am|gear|carb|
# +-----------+----+---+-----+---+----+----+-----+---+---+----+----+
# | Duster 360|14.3|  8|360.0|245|3.21|3.57|15.84|  0|  0|   3|   4|
# |  Merc 280C|17.8|  6|167.6|123|3.92|3.44| 18.9|  1|  0|   4|   4|
# | Merc 450SE|16.4|  8|275.8|180|3.07|4.07| 17.4|  0|  0|   3|   3|
# | Merc 450SL|17.3|  8|275.8|180|3.07|3.73| 17.6|  0|  0|   3|   3|
# |Merc 450SLC|15.2|  8|275.8|180|3.07|3.78| 18.0|  0|  0|   3|   3|
# +-----------+----+---+-----+---+----+----+-----+---+---+----+----+
# only showing top 5 rows

# %%
# define sample DataFrame 1 

data = [("A101", "John"), ("A102", "Peter"), ("A103", "Charlie")] 

columns = ["emp_id", "emp_name"] 

dataframe_1 = spark.createDataFrame(data, columns)

# %%
 
data = [("A101", 1000), ("A102", 2000), ("A103", 3000)]

columns = ["emp_id", "salary"]

dataframe_2 = spark.createDataFrame(data, columns)

# %%
# create a new DataFrame, "combined_df" by performing an inner join

combined_df = dataframe_1.join(dataframe_2, on="emp_id", how="inner")

# %%
# define sample DataFrame 1

data = [("A101", 1000), ("A102", 2000), ("A103",None)]

columns = ["emp_id", "salary"]

dataframe_1 = spark.createDataFrame(data, columns)

# %%
filled_df = dataframe_1.fillna({"salary": 3000}) 
filled_df.head(3)
# Out:
# [Row(emp_id='A101', salary=1000),
#  Row(emp_id='A102', salary=2000),
#  Row(emp_id='A103', salary=3000)]

# %%
sdf.groupby(['cyl'])\
.agg({"wt": "AVG"})\
.show(5)
# Out:
# [Stage 15:>                                                         (0 + 8) / 8]
# +---+-----------------+
# |cyl|          avg(wt)|
# +---+-----------------+
# |  6|3.117142857142857|
# |  4|2.285727272727273|
# |  8|3.999214285714286|
# +---+-----------------+

# %%
car_counts = sdf.groupby(['cyl'])\
.agg({"wt": "count"})\
.sort("count(wt)", ascending=False)\
.show(5)
# Out:
# [Stage 18:=======>                                                  (1 + 7) / 8]
# +---+---------+
# |cyl|count(wt)|
# +---+---------+
# |  8|       14|
# |  4|       11|
# |  6|        7|
# +---+---------+

# %%
sdf.filter(sdf["cyl"] > 5).show(5)
# Out:
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# |       Unnamed: 0| mpg|cyl| disp| hp|drat|   wt| qsec| vs| am|gear|carb|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# |        Mazda RX4|21.0|  6|160.0|110| 3.9| 2.62|16.46|  0|  1|   4|   4|
# |    Mazda RX4 Wag|21.0|  6|160.0|110| 3.9|2.875|17.02|  0|  1|   4|   4|
# |   Hornet 4 Drive|21.4|  6|258.0|110|3.08|3.215|19.44|  1|  0|   3|   1|
# |Hornet Sportabout|18.7|  8|360.0|175|3.15| 3.44|17.02|  0|  0|   3|   2|
# |          Valiant|18.1|  6|225.0|105|2.76| 3.46|20.22|  1|  0|   3|   1|
# +-----------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# only showing top 5 rows
