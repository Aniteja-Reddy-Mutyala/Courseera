# %%
# !pip install "numpy<2.0"
# !pip install faiss-cpu==1.8.0
# !pip install "tensorflow>=2.0.0"
# !pip install --upgrade tensorflow-hub
# Out:
# Collecting numpy<2.0
#   Downloading numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
# Downloading numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 31.5 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.1
#     Uninstalling numpy-2.4.1:
#       Successfully uninstalled numpy-2.4.1
# Successfully installed numpy-1.26.4
# Requirement already satisfied: faiss-cpu==1.8.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: numpy in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from faiss-cpu==1.8.0) (1.26.4)
# Requirement already satisfied: tensorflow>=2.0.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (3.4.0)
# Requirement already satisfied: packaging in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (6.33.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (2.32.5)
# Requirement already satisfied: setuptools in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow>=2.0.0) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.0.0) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow>=2.0.0) (3.10.1)
# Requirement already satisfied: pillow in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow>=2.0.0) (12.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow>=2.0.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow>=2.0.0) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow>=2.0.0) (0.46.3)
# Requirement already satisfied: rich in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow>=2.0.0) (14.3.1)
# Requirement already satisfied: namex in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow>=2.0.0) (0.1.0)
# Requirement already satisfied: optree in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow>=2.0.0) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow>=2.0.0) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow>=2.0.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow>=2.0.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow>=2.0.0) (0.1.2)
# Requirement already satisfied: tensorflow-hub in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow-hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow-hub) (6.33.4)
# Requirement already satisfied: tf-keras>=2.14.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow-hub) (2.20.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tf-keras>=2.14.1->tensorflow-hub) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (3.4.0)
# Requirement already satisfied: packaging in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (25.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (2.32.5)
# Requirement already satisfied: setuptools in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (3.10.1)
# Requirement already satisfied: pillow in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (12.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (0.46.3)
# Requirement already satisfied: rich in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (14.3.1)
# Requirement already satisfied: namex in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (0.1.0)
# Requirement already satisfied: optree in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-hub) (0.1.2)

# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import faiss
import re
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from pprint import pprint

def warn(*args , **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')
# Out:
# /Users/anirudh/.local/share/virtualenvs/Desktop-sFnGVMJ4/lib/python3.11/site-packages/tensorflow_hub/__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version

# %%
newsgroups_train = fetch_20newsgroups(subset='train')
pprint(list(newsgroups_train.target_names))
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
newsgroups = fetch_20newsgroups(subset = "all")
documents = newsgroups.data
#Basic preprocessing of text data
def preprocess_text(text):
    # Remove email headers
    text = re.sub(r'^From:.*\n?', '', text, flags=re.MULTILINE)
    # Remove email addresses
    text = re.sub(r'\S*@\S*\s?', '', text)
    # Remove punctuations and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Convert to lowercase
    text = text.lower()
    # Remove excess whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Preprocess each document
processed_documents = [preprocess_text(doc) for doc in documents]

# %%
# Choose a sample post to display
sample_index = 0  # for example, the first post in the dataset

# Print the original post
print("Original post:\n")
print(newsgroups_train.data[sample_index])
print("\n" + "-"*80 + "\n")

# Print the preprocessed post
print("Preprocessed post:\n")
print(preprocess_text(newsgroups_train.data[sample_index]))
print("\n" + "-"*80 + "\n")
# Out:
# Original post:
#
# From: lerxst@wam.umd.edu (where's my thing)
# Subject: WHAT car is this!?
# Nntp-Posting-Host: rac3.wam.umd.edu
# Organization: University of Maryland, College Park
# Lines: 15
#
#  I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.
#
# Thanks,
# - IL
#    ---- brought to you by your neighborhood Lerxst ----
#
#
#
#
#
#
# --------------------------------------------------------------------------------
#
# Preprocessed post:
#
# subject what car is this nntppostinghost racwamumdedu organization university of maryland college park lines i was wondering if anyone out there could enlighten me on this car i saw the other day it was a door sports car looked to be from the late s early s it was called a bricklin the doors were really small in addition the front bumper was separate from the rest of the body this is all i know if anyone can tellme a model name engine specs years of production where this car is made history or whatever info you have on this funky looking car please email thanks il brought to you by your neighborhood lerxst
#
# --------------------------------------------------------------------------------

# %%
# Load the Universal sentence encoder's tf hub module
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
#Function to generate embeddings
def embed_text(text):
    return embed(text).numpy()
# Generate embeddings for each preprocessed document
X_use = np.vstack([embed_text([doc]) for doc in processed_documents])

# %%
dimension = X_use.shape[1]
index = faiss.IndexFlatL2(dimension) # Creating Faiss Index
index.add(X_use) # Adding the document vectors to the index

# %%
# Function to perform a query using the Faiss index
def search(query_text, k=5):
    # Preprocess the query text
    preprocessed_query = preprocess_text(query_text)
    # Generate the query vector
    query_vector = embed_text([preprocessed_query])
    # Perform the search
    distances, indices = index.search(query_vector.astype('float32'), k)
    return distances, indices

# Example Query
query_text = "motorcycle"
distances, indices = search(query_text)

# Display the results
for i, idx in enumerate(indices[0]):
    # Ensure that the displayed document is the preprocessed one
    print(f"Rank {i+1}: (Distance: {distances[0][i]})\n{processed_documents[idx]}\n")
# Out:
# Rank 1: (Distance: 1.0367169380187988)
# subject first bike organization freshman mechanical engineering carnegie mellon pittsburgh pa lines nntppostinghost andrewcmuedu anyone i am a serious motorcycle enthusiast without a motorcycle and to put it bluntly it sucks i really would like some advice on what would be a good starter bike for me i do know one thing however i need to make my first bike a good one because buying a second any time soon is out of the question i am specifically interested in racing bikes cbr f gsxr i know that this may sound kind of crazy considering that ive never had a bike before but i am responsible a fast learner and in love please give me any advice that you think would help me in my search including places to look or even specific bikes that you want to sell me thanks jamie belliveau
#
# Rank 2: (Distance: 1.0392436981201172)
# subject first bike organization freshman mechanical engineering carnegie mellon pittsburgh pa lines nntppostinghost poandrewcmuedu anyone i am a serious motorcycle enthusiast without a motorcycle and to put it bluntly it sucks i really would like some advice on what would be a good starter bike for me i do know one thing however i need to make my first bike a good one because buying a second any time soon is out of the question i am specifically interested in racing bikes cbr f gsxr i know that this may sound kind of crazy considering that ive never had a bike before but i am responsible a fast learner and in love please give me any advice that you think would help me in my search including places to look or even specific bikes that you want to sell me thanks jamie belliveau
#
# Rank 3: (Distance: 1.051562786102295)
# subject re first bike organization microsoft corporation lines in recmotorcycles james leo belliveau writes i am a serious motorcycle enthusiast without a motorcycle and to put it bluntly it sucks i really would like some advice on what would be a good starter bike for me i do know one thing however i need to make my first bike a good one because buying a second any time soon is out of the question i am specifically interested in racing bikes cbr f gsxr i know that this may sound kind of crazy considering that ive never had a bike before but i am responsible a fast learner and in love responsible and in love i believe thats a contradiction in terms unless youre really brave read reckless a cc sport bike will go way faster than you dare for at least your first year of riding getting more than that really is overkill as youll never even want to use it the following bikes can be bought and repaired cheaply are easy for a novice to manage and are plenty high performance kawasaki ex honda vf interceptor suzuki gse the mph time of the ex at full throttle is way sooner than youre ready for it with something as small as a youd probably be wishing for more power pretty quickly unless its a tzr or rgv now im not saying that youre certain to kill yourself immediately with a f or a gsxr plenty of people have started riding on those bikes and done just fine what i am saying is that its a waste of money and a waste of perfectly good plastic when you drop the thing learning how to balance while stopping youll never get the throttle more than half open anyway so why spend the extra bucks chris
#
# Rank 4: (Distance: 1.0526403188705444)
# subject re new to motorcycles organization hp sonoma county srsdmwtdmid xnewsreader tin version pl lines gregory humphreys wrote greg im very new to motorcycles havent even bought one yet i was in the same position about you how do you learn if youve never ridden i took a class put on by a group called the motorcycle safety foundation in california they might have something similar in washington try calling a motorcycle dealer in your area and asking its a good first start on how to ride a motorcycle correctly
#
# Rank 5: (Distance: 1.0647422075271606)
# subject re first bike and wheelies organization st elizabeth hospital youngstown oh lines replyto john r daker nntppostinghost yfnysuedu in a previous article james leo belliveau says anyone i am a serious motorcycle enthusiast without a motorcycle and to put it bluntly it sucks i really would like some advice on what would be a good starter bike for me i do know one thing however i need to make my first bike a good one because buying a second any time soon is out of the question i am specifically interested in racing bikes cbr f gsxr i know that this may sound kind of crazy considering that ive never had a bike before but i am responsible a fast learner and in love please give me any advice that you think would help me in my search including places to look or even specific bikes that you want to sell me thanks the answer is obvious zx d dod darkman the significant problems we face cannot be solved at the same level of thinking we were at when we created them albert einstein the eternal champion

# %%
# Display the results
for i, idx in enumerate(indices[0]):
    # Displaying the original (unprocessed) document corresponding to the search result
    print(f"Rank {i+1}: (Distance: {distances[0][i]})\n{documents[idx]}\n")
# Out:
# Rank 1: (Distance: 1.0367169380187988)
# From: James Leo Belliveau <jbc9+@andrew.cmu.edu>
# Subject: First Bike??
# Organization: Freshman, Mechanical Engineering, Carnegie Mellon, Pittsburgh, PA
# Lines: 17
# NNTP-Posting-Host: andrew.cmu.edu
#
#  Anyone,
#
#     I am a serious motorcycle enthusiast without a motorcycle, and to
# put it bluntly, it sucks.  I really would like some advice on what would
# be a good starter bike for me.  I do know one thing however, I need to
# make my first bike a good one, because buying a second any time soon is
# out of the question.  I am specifically interested in racing bikes, (CBR
# 600 F2, GSX-R 750).  I know that this may sound kind of crazy
# considering that I've never had a bike before, but I am responsible, a
# fast learner, and in love.  Please give me any advice that you think
# would help me in my search, including places to look or even specific
# bikes that you want to sell me.
#
#     Thanks  :-)
#
#     Jamie Belliveau (jbc9@andrew.cmu.edu)
#
#
#
# Rank 2: (Distance: 1.0392436981201172)
# From: James Leo Belliveau <jbc9+@andrew.cmu.edu>
# Subject: First Bike??
# Organization: Freshman, Mechanical Engineering, Carnegie Mellon, Pittsburgh, PA
# Lines: 17
# NNTP-Posting-Host: po2.andrew.cmu.edu
#
#  Anyone,
#
#     I am a serious motorcycle enthusiast without a motorcycle, and to
# put it bluntly, it sucks.  I really would like some advice on what would
# be a good starter bike for me.  I do know one thing however, I need to
# make my first bike a good one, because buying a second any time soon is
# out of the question.  I am specifically interested in racing bikes, (CBR
# 600 F2, GSX-R 750).  I know that this may sound kind of crazy
# considering that I've never had a bike before, but I am responsible, a
# fast learner, and in love.  Please give me any advice that you think
# would help me in my search, including places to look or even specific
# bikes that you want to sell me.
#
#     Thanks  :-)
#
#     Jamie Belliveau (jbc9@andrew.cmu.edu)
#
#
#
# Rank 3: (Distance: 1.051562786102295)
# From: chrispi@microsoft.com (Chris Pirih)
# Subject: Re: First Bike??
# Organization: Microsoft Corporation
# Lines: 39
#
# In rec.motorcycles James Leo Belliveau <jbc9+@andrew.cmu.edu> writes:
# ;    I am a serious motorcycle enthusiast without a motorcycle, and to
# ;put it bluntly, it sucks.  I really would like some advice on what would
# ;be a good starter bike for me.  I do know one thing however, I need to
# ;make my first bike a good one, because buying a second any time soon is
# ;out of the question.  I am specifically interested in racing bikes, (CBR
# ;600 F2, GSX-R 750).  I know that this may sound kind of crazy
# ;considering that I've never had a bike before, but I am responsible, a
# ;fast learner, and in love.
#
# Responsible and in love?  I believe that's a contradiction
# in terms.
#
# Unless you're really brave (read: "reckless") a 500cc sport
# bike will go way faster than you dare for at least your first
# year of riding.  Getting more than that really is overkill,
# as you'll never even want to use it.  The following bikes
# can be bought (and repaired!) cheaply, are easy for a novice
# to manage, and are plenty high performance:
#     Kawasaki EX-500
#     Honda VF-500 "Interceptor"
#     Suzuki GS-550E
#
# The 0-100mph time of the EX-500 at full throttle is "way
# sooner than you're ready for it".  :-)  With something
# as small as a 250, you'd probably be wishing for more
# power pretty quickly (unless it's a TZR or RGV :).
#
# Now, I'm not saying that you're 100% certain to kill
# yourself immediately with a 600f2 or a GSXR-750.  Plenty
# of people have started riding on those bikes and done
# just fine.  What I am saying is that it's a waste of
# money, and a waste of perfectly good plastic when you
# drop the thing learning how to balance while stopping.
# You'll never get the throttle more than half open
# anyway, so why spend the extra 2000 bucks?
#
# ---
# chris
#
#
# Rank 4: (Distance: 1.0526403188705444)
# From: blaisec@sr.hp.com (Blaise Cirelli)
# Subject: Re: New to Motorcycles...
# Organization: HP Sonoma County (SRSD/MWTD/MID)
# X-Newsreader: TIN [version 1.1 PL8.8]
# Lines: 15
#
# Gregory Humphreys (gregh@niagara.dcrt.nih.gov) wrote:
#
#
#
# Greg,
#
# I'm very new to motorcycles. Haven't even bought one yet. I was in the same
# position about you. How do you learn if you've never ridden.
#
# I took a class put on by a group called the Motorcycle Safety Foundation
# in California. They might have something similar in Washington.
#
# Try calling a motorcycle dealer in your area and asking. It's a good first
# start on how to ride a motorcycle correctly.
#
#
#
# Rank 5: (Distance: 1.0647422075271606)
# From: ak296@yfn.ysu.edu (John R. Daker)
# Subject: Re: First Bike?? and Wheelies
# Organization: St. Elizabeth Hospital, Youngstown, OH
# Lines: 24
# Reply-To: ak296@yfn.ysu.edu (John R. Daker)
# NNTP-Posting-Host: yfn.ysu.edu
#
#
# In a previous article, jbc9+@andrew.cmu.edu (James Leo Belliveau) says:
#
# > Anyone,
# >
# >    I am a serious motorcycle enthusiast without a motorcycle, and to
# >put it bluntly, it sucks.  I really would like some advice on what would
# >be a good starter bike for me.  I do know one thing however, I need to
# >make my first bike a good one, because buying a second any time soon is
# >out of the question.  I am specifically interested in racing bikes, (CBR
# >600 F2, GSX-R 750).  I know that this may sound kind of crazy
# >considering that I've never had a bike before, but I am responsible, a
# >fast learner, and in love.  Please give me any advice that you think
# >would help me in my search, including places to look or even specific
# >bikes that you want to sell me.
# >
# >    Thanks  :-)
#
# The answer is obvious: ZX-11 D.
# --
# DoD #650<----------------------------------------------------------->DarkMan
#    The significant problems we face cannot be solved at the same level of
#       thinking we were at when we created them.   - Albert Einstein
#          ___________________The Eternal Champion_________________
