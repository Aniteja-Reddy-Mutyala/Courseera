# %%
# %run "restaurant_data_management.py"
# Out:
#   File ~/Desktop/Courseera/IBM-RAG and agentic AI/RAG and Agentic AI Capstone Project/restaurant_data_management.py:279
#     if os.path.exists(self.test_file_backup):
#     ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
# %run "mcp-test1.py"
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Desktop/Courseera/IBM-RAG and agentic AI/RAG and Agentic AI Capstone Project/mcp-test1.py:18
#      16             print("--- END SCREENSHOT ---\n")
#      17 if __name__ == "__main__":
# ---> 18     asyncio.run(run_test())
#      19     #await run_test()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/runners.py:186, in run(main, debug)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    182     asyncio.run(main())
#     183 """
#     184 if events._get_running_loop() is not None:
#     185     # fail fast with short traceback
# --> 186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
# ...

# %%
# !python3 mcp-test1.py
# Out:
# ╭────────────────────────────────────────────────────────────────────────────╮
# │                                                                            │
# │        _ __ ___  _____           __  __  _____________    ____    ____     │
# │       _ __ ___ .'____/___ ______/ /_/  |/  / ____/ __ \  |___ \  / __ \    │
# │      _ __ ___ / /_  / __ `/ ___/ __/ /|_/ / /   / /_/ /  ___/ / / / / /    │
# │     _ __ ___ / __/ / /_/ (__  ) /_/ /  / / /___/ ____/  /  __/_/ /_/ /     │
# │    _ __ ___ /_/    \____/____/\__/_/  /_/\____/_/      /_____(*)____/      │
# │                                                                            │
# │                                                                            │
# │                                FastMCP  2.0                                │
# │                                                                            │
# │                                                                            │
# ...

# %%
# !python3 "mcp-client.py"
# Out:
# Enter GROQ_API_KEY: Traceback (most recent call last):
#   File "/Users/anirudh/Desktop/Courseera/IBM-RAG and agentic AI/RAG and Agentic AI Capstone Project/mcp-client.py", line 21, in <module>
#     set_if_undefined("GROQ_API_KEY")
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/anirudh/Desktop/Courseera/IBM-RAG and agentic AI/RAG and Agentic AI Capstone Project/mcp-client.py", line 20, in set_if_undefined
#     os.environ[var] = getpass.getpass(f"Enter {var}: ")
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/getpass.py", line 77, in unix_getpass
#     passwd = _raw_input(prompt, stream, input=input)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/getpass.py", line 146, in _raw_input
#     line = input.readline()
#            ^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !python3 "mcp-client.py"
# Out:
# ------------------------------------------------------------
# Demo: get_restaurant_info('Iron & Embers')
# ------------------------------------------------------------
#
#
# ╭────────────────────────────────────────────────────────────────────────────╮
# │                                                                            │
# │        _ __ ___  _____           __  __  _____________    ____    ____     │
# │       _ __ ___ .'____/___ ______/ /_/  |/  / ____/ __ \  |___ \  / __ \    │
# │      _ __ ___ / /_  / __ `/ ___/ __/ /|_/ / /   / /_/ /  ___/ / / / / /    │
# │     _ __ ___ / __/ / /_/ (__  ) /_/ /  / / /___/ ____/  /  __/_/ /_/ /     │
# │    _ __ ___ /_/    \____/____/\__/_/  /_/\____/_/      /_____(*)____/      │
# │                                                                            │
# │                                                                            │
# │                                FastMCP  2.0                                │
# ...

# %%
import json

with open("augmented_user_review.json", "r") as f:
    reviews = json.load(f)

# Check first review keys
print(reviews[0].keys())
print(reviews[0])
# Out:
# dict_keys(['reviewId', 'userId', 'itemId', 'title', 'text', 'date', 'rating', 'language', 'images', 'image_captions'])
# ...
